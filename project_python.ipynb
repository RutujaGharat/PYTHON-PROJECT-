# %%
# to import beautifulsoup library
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#import library and webdrive

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
#create the object of service class to open a  ChromeDriver that matches your installed version of Google Chrome.
service = Service(ChromeDriverManager().install())


driver = webdriver.Chrome(service=service)

# %%
# to open the site to browser 

driver.get('https://in.puma.com/in/en/womens')
driver.refresh()

# %%
# to check the code 

soup = BeautifulSoup(driver.page_source,"html.parser")

print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="https://qoerum.yottaa-prod.com" rel="preconnect"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/destination?id=AW-948078999&amp;l=dataLayer&amp;cx=c&amp;gtm=45He4c40v857388056za200" type="text/javascript">
#   </script>
#   <script src="https://rapid-cdn.yottaa.com/rapid/lib/5D5Pv6UiiLiFyA.js" type="text/javascript">
#   </script>
#   <link href="https://cdn-eu.dynamicyield.com" rel="preconnect"/>
#   <link href="https://st-eu.dynamicyield.com" rel="preconnect"/>
#   <link href="https://rcom-eu.dynamicyield.com" rel="preconnect"/>
#   <link href="https://cdn-eu.dynamicyield.com" rel="dns-prefetch"/>
#   <link href="https://st-eu.dynamicyield.com" rel="dns-prefetch"/>
#   <link href="https://rcom-eu.dynamicyield.com" rel="dns-prefetch"/>
# ...

# %%
# to extract product name (div)


title_h3 = soup.find_all('div', attrs={'class' : "flex flex-col w-full"})

title_h3
# Out:
# [<div class="flex flex-col w-full"><h3 class="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2">Tori Pixie Res Women's Sneakers<span class="sr-only">PUMA White-Lavendar Pop-Pale Lemon-PRISM PINK</span></h3></div>,
#  <div class="flex flex-col w-full"><h3 class="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2">Tori Pixie Res Women's Sneakers<span class="sr-only">Pristine-Light Sand-Island Pink</span></h3></div>,
#  <div class="flex flex-col w-full"><h3 class="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2">Mayze Wedge Women's Sneakers<span class="sr-only">Puma White-Puma Black</span></h3></div>,
#  <div class="flex flex-col w-full"><h3 class="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2">Mayze Leather Women's Sneakers<span class="sr-only">PUMA White-Mauved Out</span></h3></div>,
# ...

# %%
# to create a empty list and extract the title name

titles =[]


for title in title_h3:
    titles.append(title.text)

titles
# Out:
# ["Tori Pixie Res Women's SneakersPUMA White-Lavendar Pop-Pale Lemon-PRISM PINK",
#  "Tori Pixie Res Women's SneakersPristine-Light Sand-Island Pink",
#  "Mayze Wedge Women's SneakersPuma White-Puma Black",
#  "Mayze Leather Women's SneakersPUMA White-Mauved Out",
#  "Carina Slim Perf Women's SneakersPUMA White-PUMA Gold",
#  "PUMA Surgestride Women's Training ShoesPale Plum-PUMA Black-PUMA White",
#  "PUMA Surgestride Women's Training ShoesFeather Gray-Cool Mid Gray-Mint",
#  "PUMA Exoteric Women's Running ShoesTeam Violet-PUMA Black-PUMA Silver",
#  "Softride Ruby Better Women's Running ShoesPUMA Black-Warm White-PUMA Silver",
#  "Silvia V4 Women's SlidesPlatinum Gray-Blue Wash-Evening Sky",
#  "Flyer Runner Engineered Knit Women's ShoesFoxglove-PUMA White",
#  "Softride Sophia 2 Res Women's Slip-On ShoesCool Light Gray-Lavender Alert",
#  "Court Classic Women's SneakersPUMA White-Archive Green",
#  "Royalcat Comfort SOFTRIDE Women's SlidesPUMA Black-PUMA Silver",
# ...

# %%
# to extract price 

price_span = soup.find_all('span', attrs={'class': 'whitespace-nowrap text-base text-puma-red font-bold'})

price_span
# Out:
# [<span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹3,599</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹3,599</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹5,999</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹4,799</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹2,109</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹3,049</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹3,049</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹2,599</span>,
#  <span class="whitespace-nowrap text-base text-puma-red font-bold" data-test-id="sale-price">₹4,899</span>,
# ...

# %%
# to create a empty list and extract the price 

prices = []


for price in price_span:
   p =  price.text
   p = p.replace(',','')
   p = p.replace('₹','')

   prices.append(int(p))



prices
# Out:
# [3599,
#  3599,
#  5999,
#  4799,
#  2109,
#  3049,
#  3049,
#  2599,
#  4899,
#  1599,
#  3299,
#  4399,
#  3299,
#  2239,
#  1839,
#  4899,
#  1999,
#  4199,
#  7799,
#  11999,
#  2349,
#  3299]

# %%
#oirgnal price 
og_price  = soup.find_all('span', attrs={'class': "whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100"})

og_price
# Out:
# [<span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹5,999</span>,
#  <span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹5,999</span>,
#  <span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹9,999</span>,
#  <span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹7,999</span>,
#  <span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹4,499</span>,
#  <span class="whitespace-nowrap text-base line-through opacity-50 override:text-puma-black-300 override:opacity-100" data-test-id="price">₹6,499</span>,
# ...

# %%
# to extract orignal price 
ogprices = []


for pr in og_price:
   p =  pr.text
   p = p.replace(',','')
   p = p.replace('₹','')
   ogprices.append(int(p))

ogprices
# Out:
# [5999,
#  5999,
#  9999,
#  7999,
#  4499,
#  6499,
#  6499,
#  4999,
#  6999,
#  1999,
#  5499,
#  5499,
#  5499,
#  2799,
#  2299,
#  6999,
#  2499,
#  6999,
#  11999,
#  19999,
#  4999,
#  5499]

# %%
# to extract discount
discount_per   = soup.find_all('span', attrs={'class': "min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]"})

discount_per
# Out:
# [<span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-40%</span>,
#  <span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-40%</span>,
#  <span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-40%</span>,
#  <span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-40%</span>,
#  <span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-53%</span>,
#  <span class="min-w-content tw-1ghqyvy tw-noc9l0 absolute top-0 left-0 z-[5]" data-test-id="product-badge-sale" data-uds-child="badge">-53%</span>,
# ...

# %%
discounts =[]


for dis in discount_per:
    discounts.append(dis.text)

discounts
# Out:
# ['-40%',
#  '-40%',
#  '-40%',
#  '-40%',
#  '-53%',
#  '-53%',
#  '-53%',
#  '-48%',
#  '-30%',
#  '-20%',
#  '-40%',
#  '-20%',
#  '-40%',
#  '-20%',
#  '-20%',
#  '-30%',
#  '-20%',
#  '-40%',
#  '-35%',
#  '-40%',
#  '-53%',
#  '-40%']

# %%
import pandas as pd

# %%
len(discounts)
# Out:
# 22

# %%
len(titles)
# Out:
# 24

# %%
len(prices)
# Out:
# 22

# %%
len(ogprices)
# Out:
# 22

# %%
# create dataframe 


df = pd.DataFrame({'Title': titles[24-2],'price': prices,'orignal price' : ogprices,'discount' : discounts})
df
# Out:
#                                                 Title  price  orignal price  \
# 0   PUMA Exoteric Women's Running ShoesPUMA Black-...   3599           5999
# 1   PUMA Exoteric Women's Running ShoesPUMA Black-...   3599           5999
# 2   PUMA Exoteric Women's Running ShoesPUMA Black-...   5999           9999
# 3   PUMA Exoteric Women's Running ShoesPUMA Black-...   4799           7999
# 4   PUMA Exoteric Women's Running ShoesPUMA Black-...   2109           4499
# 5   PUMA Exoteric Women's Running ShoesPUMA Black-...   3049           6499
# 6   PUMA Exoteric Women's Running ShoesPUMA Black-...   3049           6499
# 7   PUMA Exoteric Women's Running ShoesPUMA Black-...   2599           4999
# 8   PUMA Exoteric Women's Running ShoesPUMA Black-...   4899           6999
# 9   PUMA Exoteric Women's Running ShoesPUMA Black-...   1599           1999
# 10  PUMA Exoteric Women's Running ShoesPUMA Black-...   3299           5499
# ...

# %%
# to create csv file 
df.to_csv("puma1.csv")
